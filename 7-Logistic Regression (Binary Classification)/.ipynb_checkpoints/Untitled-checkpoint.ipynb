# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
left = df[df['left']==1]
left.shape
# Out:
# (3571, 10)

# %%
retention = df[df['left'] == 0]
retention.shape
# Out:
# (11428, 10)

# %%
df.groupby(by='left').mean(numeric_only=True)
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
plt.title('imparct of salary to Retention')
plt.show()

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
plt.title('Departement VS Retention')
plt.show()

# %% [markdown]
# ### build logistic regression model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
X
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
y= df['left']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %% [markdown]
# # Convert Salarys to numeric values

# %%
salary = pd.get_dummies(X.salary,dtype=int)
salary
# Out:
#        high  low  medium
# 0         0    1       0
# 1         0    0       1
# 2         0    0       1
# 3         0    1       0
# 4         0    1       0
# ...     ...  ...     ...
# 14994     0    1       0
# 14995     0    1       0
# 14996     0    1       0
# 14997     0    1       0
# 14998     0    1       0
#
# [14999 rows x 3 columns]

# %%
merged = pd.concat([X,salary],axis=1)
merged
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  high  low  medium
# 0         low     0    1       0
# 1      medium     0    0       1
# ...

# %%
final = merged.drop(['salary'],axis=1)
final
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 0                    0.38                   157                      0     0
# 1                    0.80                   262                      0     0
# 2                    0.11                   272                      0     0
# 3                    0.72                   223                      0     0
# 4                    0.37                   159                      0     0
# ...                   ...                   ...                    ...   ...
# 14994                0.40                   151                      0     0
# 14995                0.37                   160                      0     0
# 14996                0.37                   143                      0     0
# 14997                0.11                   280                      0     0
# 14998                0.37                   158                      0     0
#
#        low  medium
# 0        1       0
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(final,y,test_size=0.9)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 14978    1
# 5497     0
# 459      1
# 11302    0
# 12641    1
#         ..
# 3251     0
# 255      1
# 12909    0
# 453      1
# 7456     0
# Name: left, Length: 13500, dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 0.7868148148148149
